# %% [markdown]
# # Prompt Engineering
#
# Modified from the file `Lab_Prompt_Engineering.ipynb`
#
# #### _Goal: See how even small amounts of data can make an LLM much more useful!_

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/dcai_lab/dcai-lab/prompt_engineering/
# Out:
# /content/drive/MyDrive/dcai_lab/dcai-lab/prompt_engineering

# %%
# !pwd
# Out:
# /content/drive/MyDrive/dcai_lab/dcai-lab/prompt_engineering

# %%
# !pip install -q groq
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.9/108.9 kB 2.7 MB/s eta 0:00:00

# %%
import os
from groq import Groq
from google.colab import userdata

# %%
client = Groq(
    api_key=userdata.get('GROQ_API_KEY'),
)

# %%
def get_completion(llm_prompt, model, options={}):
    response = client.chat.completions.create(
        messages=[
            {"role": "user", "content":llm_prompt},
        ],
        model=model,
        **options
    )
    completion = response.choices[0].message.content
    return completion

# %% [markdown]
# ### Scenario
#
# You have a lot of email you have to write for the different extracurriculars: movie, running, and math clubs. So, you want to use an LLM to help you write them.

# %% [markdown]
# ### Exercise 1
#
# You have the following code written, so your LLM can write emails for all your clubs. But it writes a random email. You have no control over what the subject of them will be.
#
# **Your task: Adjust the context to enable you to specify the subject of the email.**
#
# _Goal: Learn how to build reusable contexts/prompts!_

# %%
# Build a template for giving context to your LLM; TODO: change the context to take in any subject
context = "Write an email for the {{club_name}} club with the subject: {{subject}}." # double curly braces indicate a variable

my_club_names = ['movie', 'running', 'math']
subjects = [
    'Inviting suggestions for next movie screening',
    'New marathon alert!',
    'Seminar on advanced probability',
]
for i in range(len(my_club_names)):
  # Run your LLM, looping through your different clubs
  club_name = my_club_names[i]
  subject = subjects[i]

  llm_prompt = context
  llm_prompt = llm_prompt.replace("{{club_name}}", club_name)
  llm_prompt = llm_prompt.replace("{{subject}}", subject)

  output = get_completion(llm_prompt, "llama-3.2-90b-text-preview")
  print(output)
  print("--------------")
# Out:
# Subject: Inviting suggestions for next movie screening
#
# Dear Movie Club Members,
#
# I hope this email finds you all well. As we have decided our next movie screening date, it's time for us to choose the film we would like to watch. We are now inviting suggestions from all members for the next movie screening.
#
# We encourage you to suggest any movie, whether it's a classic, a recent release, a foreign film, or any other type that you think the club would enjoy. You can consider various genres such as drama, comedy, thriller, sci-fi, or any other that suits your taste.
#
# If you would like to suggest a movie, please reply to this email with the title of the movie and a brief description (optional) about why you think the club would enjoy it. You can also include a trailer link if available.
#
# We will collect all the suggestions and have a group discussion to decide on our next movie. The deadline for submitting suggestions is [insert date]. We will then send out a voting email to the group, and the movie with the most votes will be our next screening choice.
#
# Feel free to be creative and suggest any movie that you're passionate about. We look forward to hearing your ideas and watching our next film together.
#
# Best regards,
# [Your Name]
# Movie Club Organizer
# --------------
# Subject: New marathon alert!
#
# Dear Running Club Members,
#
# We are excited to announce that a new marathon has been scheduled for [Date] in [Location]. This event promises to be an exciting challenge for runners of all levels, and we encourage all club members to participate.
#
# Here are the event details:
#
# - Event Name: [Marathon Name]
# - Date: [Date]
# - Location: [Location]
# - Distance: 42.195 kilometers (standard marathon distance)
# - Course Description: [Briefly describe the course]
#
# Registration for the event is now open and will close on [Registration Deadline]. To secure your spot, please follow the registration link provided below:
#
# [Registration Link]
#
# As always, we will be organizing a group meetup and carpool for the event. If you are interested in joining us, please reply to this email by [RSVP Deadline] so we can make the necessary arrangements.
#
# Additionally, we will be offering training sessions and workshops leading up to the event to help you prepare. These sessions will include:
#
# - Long distance runs
# - Speed and agility training
# - Nutrition and recovery advice
#
# A detailed training schedule will be sent out separately.
#
# If you have any questions or concerns, please don't hesitate to reach out to us. We look forward to seeing you all at the starting line!
#
# Best regards,
# [Your Name]
# Running Club Organizer
# --------------
# Subject: Seminar on Advanced Probability
#
# Dear Math Club Members,
#
# I hope this email finds you well. As part of our ongoing efforts to enhance our understanding of mathematical concepts and provide a platform for knowledge sharing, the Math Club is excited to announce an upcoming seminar on Advanced Probability.
#
# **Seminar Details:**
#
# * Date: [Insert Date and Time]
# * Location: [Insert Venue or Online Platform]
# * Topic: Advanced Probability: Concepts and Applications
# * Speaker: [Insert Speaker's Name and Bio]
#
# In this seminar, we will delve into the realm of advanced probability, exploring concepts such as stochastic processes, Bayesian inference, and random graphs. Our speaker, [Speaker's Name], is an expert in the field and will provide an engaging and insightful presentation, followed by a Q&A session.
#
# **Agenda:**
#
# * Introduction to advanced probability concepts
# * Stochastic processes and their applications
# * Bayesian inference and its real-world implications
# * Random graphs and network analysis
# * Q&A session and discussion
#
# **Who Should Attend:**
#
# This seminar is open to all Math Club members, particularly those with an interest in probability theory and its applications. We encourage undergraduate and graduate students, as well as faculty members, to attend and engage in the discussion.
#
# **Registration:**
#
# To register for the seminar, please reply to this email by [Insert Date] with your name, affiliation, and a brief statement of interest in the topic. This will help us plan for the event and ensure that we have adequate seating and resources.
#
# **Contact:**
#
# If you have any questions or concerns, please feel free to reach out to me at [Your Email Address]. I look forward to seeing you at the seminar!
#
# Best regards,
#
# [Your Name]
# Math Club Organizer
# --------------

# %% [markdown]
# ### Exercise 2
# The emails you're seeing don't sound like you. You sound better, funnier, or at least more like _you_! Good thing you have a few examples of emails you've written before for each club.
#
# **Your task: Given your past emails (provided for you), build a context template to include your past emails and fit a new LLM. Run and compare results.**
#
# _Goal: Observe the impact of more data._
#
# How does it do?

# %%
# @markdown #### Setup: Fetch email files

# !wget -q -O "movie_club.txt" "https://drive.google.com/uc?export=download&id=1dWKvcCIp-XwNBZ6heb5k2Y1tbdPl3WTE"
# !wget -q -O "running_club.txt" "https://drive.google.com/uc?export=download&id=1SxeE-0XP4ggjUNYwMD3VQlm_idCHoG9G"
# !wget -q -O "math_club.txt" "https://drive.google.com/uc?export=download&id=12z3EuOauuYc4Y9tdDGENs-_2wmvyErmv"

# print('Got all the emails!')

# %%
with open('movie_club.txt', 'r') as f:
  past_movie_club_emails = f.read()
with open('running_club.txt', 'r') as f:
  past_running_club_emails = f.read()
with open('math_club.txt', 'r') as f:
  past_math_club_emails = f.read()

# TODO (same code as above, without your changes for subject in Exercise 1)
context = """Read carefully some of the emails I have written \
and pay attention to my writing style.
<< My old emails start >>
{{old_emails}}
<< My old emails end >>

Write an email for the {{club_name}} club with the subject: {{subject}}.
Copy my writing style."""

my_club_names = ['movie', 'running', 'math']
old_emails_dict = {
    'movie': past_movie_club_emails,
    'running': past_running_club_emails,
    'math': past_math_club_emails,
}
subjects = [
    'Inviting suggestions for next movie screening',
    'New marathon alert!',
    'Seminar on advanced probability',
]
for i in range(len(my_club_names)):
  club_name = my_club_names[i]
  subject = subjects[i]
  old_emails = old_emails_dict[club_name]

  llm_prompt = context
  llm_prompt = llm_prompt.replace("{{old_emails}}", old_emails)
  llm_prompt = llm_prompt.replace("{{club_name}}", club_name)
  llm_prompt = llm_prompt.replace("{{subject}}", subject)

  output = get_completion(llm_prompt, "llama-3.2-90b-text-preview")
  print(output)
  print("--------------")
# Out:
# Subject: Inviting Suggestions for Next Movie Screening
#
# Lights! Camera! Action!
#
# Movie Maestros and Cinematic Connoisseurs,
#
# Are you ready to shine your spotlight and help pick the next blockbuster for our Movie Club's screening?  We want to hear from YOU!
#
# As our members, your opinions are the star of the show, and we want to make sure we choose a movie that everyone will love. Whether you're a fan of action-packed adventures or swoon over sappy rom-coms, we want to hear your thoughts and suggestions.
#
# Reply to this email with your top picks for the next movie screening. Are you itching to see the latest superhero film? Craving a classic rom-com to swoon over? Or perhaps you're in the mood for something spooky and thrilling? Share your thoughts and help us put together the ultimate movie night!
#
# To make it even more exciting, the member who suggests the selected movie will receive a FREE ticket and a mystery prize at the next screening!
#
# Don't be a silent extra – take center stage and make your movie voice heard. Send us your suggestions and let's make some magic happen!
#
# Cheers and thanks for being part of the Movie Club crew!
#
# Best,
# The Movie Club Team
# --------------
# Subject: New Marathon Alert!
#
# Dear Running Club,
#
#  Buckle up and get ready for takeoff! The wait is finally over, and a thrilling new marathon is here to challenge your endurance and quench your thirst for victory!
#
# It's time to unleash the tigers within and go full-throttle into training mode. Are you prepared to take on the longest and toughest course yet? Dust off your favorite running shoes, slip on your thinking caps, and let's dive head-first into the unknown!
#
# So as the curtains rise on this marathon, let's rewrite the script of your limits! Push the pedal to the metal, and unleash the dynamite within you. Show the world what it means to run like a rockstar! Every step you take is a story yet untold, and every finish line crossed is a triumph waiting to be crowned.
#
# New distances will be conquered, new limits will be shattered, and a fresh chapter will be written in our team's history book. It's time to assemble the dream team: the ones who refuse to be ordinary and opt for extraordinary.
#
# Mark this in your calendars: a new marathon awaits! Will you be ready to rise up and take it on?
#
# Get set, go, and shatter the boundaries of what's possible!
#
# - Running Club
# --------------
# Subject: Seminar on Advanced Probability - Roll the Dice and Take a Chance!
#
# Dear Mathletes!
#
# Are you ready to shake the probability tree and see what falls out? Well, we're excited to announce that our next seminar is going to bring you luck, or at least a deeper understanding of advanced probability concepts!
#
# Join us as we roll the dice, draw the cards, and turn probability on its head. Our expert speaker will delve into topics like Bayes' Theorem, conditional probability, and other mind-bending techniques that will leave you wondering what's random and what's not.
#
# From tossed coins to shuffled cards, this seminar promises to give you the edge in understanding the probability game. Whether you're a wizard with numbers or just looking to spice up your statistical skills, this seminar is sure to be a high-stakes adventure!
#
# Come dressed in your favorite dice-inspired attire (optional, but why not? ) and be ready to crunch the numbers and make informed bets on the uncertainty of life.
#
# Don't miss out on this opportunity to grow your probability skills and take your analytical thinking to the next level.
#
# See you there!
#
# Sincerely,
# Math Club Organizers
# --------------

# %% [markdown]
# ### Exercise 3
#
# So you think you're funny and you prize how funny you are. But what if you can get the LLM to make you funnier?
#
# **Your task: Engineer the prompt such that you can sound funnier than you.**
#
# _Goal: Play with the model, and see where it's easy to manipulate and where it isn't. And that it is not always intuitive._

# %%
# TODO (same code as Exercise 2 to get you started, without your changes)

with open('movie_club.txt', 'r') as f:
  past_movie_club_emails = f.read()
with open('running_club.txt', 'r') as f:
  past_running_club_emails = f.read()
with open('math_club.txt', 'r') as f:
  past_math_club_emails = f.read()

context = """Read carefully some of the emails I have written \
and pay attention to my writing style.
<< My old emails start >>
{{old_emails}}
<< My old emails end >>

Write an email for the {{club_name}} club with the subject: {{subject}}.
Make it funnier than my writing style."""

my_club_names = ['movie', 'running', 'math']
old_emails_dict = {
    'movie': past_movie_club_emails,
    'running': past_running_club_emails,
    'math': past_math_club_emails,
}
subjects = [
    'Inviting suggestions for next movie screening',
    'New marathon alert!',
    'Seminar on advanced probability',
]
for i in range(len(my_club_names)):
  club_name = my_club_names[i]
  subject = subjects[i]
  old_emails = old_emails_dict[club_name]

  llm_prompt = context
  llm_prompt = llm_prompt.replace("{{old_emails}}", old_emails)
  llm_prompt = llm_prompt.replace("{{club_name}}", club_name)
  llm_prompt = llm_prompt.replace("{{subject}}", subject)

  output = get_completion(llm_prompt, "llama-3.2-90b-text-preview")
  print(output)
  print("--------------")
# Out:
# Subject: In a Cinematic Crisis: We Need Your Superhero Suggestions!
#
# Greetings, Cinephile Crusaders,
#
# The Movie Club is facing a cinematic catastrophe: we've run out of movie ideas! As our trusted sidekicks, we're turning to you for help. It's time to unleash your inner superhero and save the day (or rather, the screening schedule).
#
# We need your brilliant brains to suggest our next movie masterpiece. Whether you're a die-hard fan of rom-coms, a thrill-seeker of horror flicks, or a serious follower of serious cinema (see what we did there?), we want to hear from you.
#
# Here are the deets:
#
# - No movie is too big or too small (except maybe that one film with the talking pineapple – we're not going there).
# - Originality is key, but feel free to suggest classic favorites (we won't judge you, we promise).
# - Keep in mind our movie club's guiding mantra: "Laughter is the best genre" (don't worry, we won't actually screen a 3-hour comedy special... or will we?).
#
# Reply to this email with your movie magic, and you might just see it on the big screen. Don't be shy – after all, the power of the popcorn is in your hands!
#
# In this hour of cinematic need, we turn to you, our heroic Movie Club members. May your suggestions be guided by the eternal wisdom of MovieClubian proverb: "A good movie is like a good friend: it's always there to make you laugh, cry, or just provide an excellent excuse to eat an entire pizza by yourself."
#
# Go forth and conquer the world... of cinema!
#
# Cheers and popcorn galore,
#
# The (Currently Clueless) Movie Club Team
# --------------
# Subject: New Marathon Alert: Time to Lose Your Minds (and sanity)
#
# Dear Glorious Masochists of the Running Club,
#
# Break out the sweat-inducing smiles and the I'm-about-to-die faces, because we've got a brand new marathon to obsess over! Who needs sleep or social lives when you've got 26.2 miles of agony and ecstasy waiting for you?
#
# On a more serious note, this marathon promises to push your limits, test your willpower, and make you question every life choice that led you to this moment. BUT, we all know that's what makes it so darn exciting!
#
# So, here's the deal. We'll provide the encouraging (read: cajoling) team captains, the über-motivational playlist, and the post-marathon feast to numb the pain. You bring the determination, the stamina, and the stubborn refusal to give up (even when your legs are screaming, "NO, PLEASE, FOR THE LOVE OF GOD, STOP!").
#
# Now, before we all embark on this wild adventure, let's set some ground rules:
#
# 1. No bribery or arm-twisting to convince others to join you (we have enough of that already).
# 2. No whining (too much).
# 3. No abandoning ship at mile 10 to grab a snack and watch Netflix (though we won't judge you if you do).
#
# Signing up for this glorious madness is as simple as replying to this email with a enthusiastic (or not-so-enthusiastic) "YES, I'M IN!" Let the mind-games begin!
#
# Wishing you all the blistered feet and exhausted-yet-exhilarated moments you can handle,
#
# Running Club
# --------------
# Subject Line: Seminar on Advanced Probability: Don't Get Left in the Probability Purgatory!
#
# Greetings Mathletes!
#
# It's time to fuel your love for probability and dive headfirst into the world of uncertainty (get it?). Our upcoming seminar on Advanced Probability is not for the faint of heart – it's like navigating a casino without losing your shirt (just kidding, or are we?).
#
# Join us as we take probability to the next level (think dimensions upon dimensions) with lectures, discussions, and possibly some impromptu calculations to determine your chances of winning the next office lottery pool (just don't quit your day job).
#
# We promise you'll leave with more than just a basic knowledge of randomness – you'll have a higher chance of predicting the unpredictable (okay, maybe not, but at least you'll know when to fold 'em).
#
# Date: [Insert Date]
# Time: [Insert Time]
# Location: [Insert Location]
#
# Come ready to roll the dice, learn from our expert speaker, and maybe even master the art of confidently uttering, "The probability of this event occurring is... um, high?" Bonus points if you come dressed in your lucky probability-themed outfit (looking at you, Mathletes).
#
# RSVP to avoid a case of observational bias (are we biased towards you coming? Absolutely!).
#
# Looking forward to witnessing the laws of probability unfold in real-time with you all!
#
# Cheers,
#
# The Math Club (Your Guide to Understanding the Unpredictable)
# --------------

# %% [markdown]
# #### Great work! Hope you saw how small programmatic changes to the context for the LLM made sometimes drastic changes and improvements to how the LLM behaved. Now off to do more things with LLMs!
